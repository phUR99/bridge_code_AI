# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data_custom.csv')

# %%
data.head()
# Out:
#                           topic  \
# 0              변수 값을 할당하고 출력하라.
# 1          value의 데이터 타입을 확인하라.
# 2          입력한 값의 데이터 타입을 확인하라.
# 3  첫 번째와 두 번째 숫자의 메모리 주소를 출력하라.
# 4     정수 여부를 user_input으로 확인하라.
#
#                                             question
# 0  def variable_assignment():\n    my_number = 10...
# 1  def check_data_type(value):\n    if isinstance...
# 2  python\nuser_input = input('값을 입력하세요: ')\ndata...
# 3  python\nfirst_number = int(input('첫 번째 숫자를 입력하...
# 4  \n\npython\nuser_input = input('값을 입력하세요: ')\n...

# %%
data = pd.read_csv('1.csv')
data.head()
# Out:
#    id                                               code  \
# 0   1                     x = 10\ny = 20\nsum_xy = x + y
# 1   2            name = 'Alice'\nprint(f'Hello, {name}')
# 2   3                     is_even = lambda x: x % 2 == 0
# 3   4          my_list = [1, 2, 3, 4]\nmy_list.append(5)
# 4   5  my_dict = {'name': 'Alice', 'age': 25}\nprint(...
#
#              description                      tags
# 0    두 개의 숫자를 더하는 간단한 연산         basic, arithmetic
# 1  f-string을 사용한 문자열 포맷팅  basic, string formatting
# 2       람다 함수를 사용한 짝수 판별          lambda, function
# 3             리스트에 요소 추가              list, append
# 4          딕셔너리에서 값 가져오기        dictionary, access

# %%
data.drop('id', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data.drop('id', axis=1, inplace=True)
#       2 data.head(20)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
data.head(20)
# Out:
#                                                  code  \
# 0                      x = 10\ny = 20\nsum_xy = x + y
# 1             name = 'Alice'\nprint(f'Hello, {name}')
# 2                      is_even = lambda x: x % 2 == 0
# 3           my_list = [1, 2, 3, 4]\nmy_list.append(5)
# 4   my_dict = {'name': 'Alice', 'age': 25}\nprint(...
# 5       def greet(name):\n    return f'Hello, {name}'
# 6   class Animal:\n    def speak(self):\n        r...
# 7   class Dog(Animal):\n    def speak(self):\n    ...
# 8   with open('data.txt', 'r') as file:\n    conte...
# 9   import json\ndata = {'name': 'Alice'}\njson_st...
# 10  try:\n    result = 10 / 0\nexcept ZeroDivision...
# 11  import asyncio\nasync def main():\n    await a...
# 12  arr = [3, 1, 4, 1, 5, 9]\nsorted_arr = sorted(...
# 13  def fibonacci(n):\n    return n if n < 2 else ...
# 14      import numpy as np\narr = np.array([1, 2, 3])
# 15  import pandas as pd\ndf = pd.DataFrame({'A': [...
# ...

# %%
data.to_csv('data.csv')

# %%
data[['code', 'description']].to_csv('data.csv', index=False)
